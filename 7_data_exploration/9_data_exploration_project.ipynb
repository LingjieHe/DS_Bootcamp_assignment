# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices,
                           sheet_name='Average price', index_col=None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
pd.set_option('display.max_columns',500)
pd.set_option('display.max_row',500)

# %%
properties.head(10)
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
# 5 1995-05-01    84409.14932        53042.24852  90258.00033  63997.13588
# 6 1995-06-01    94900.51244        53700.34831  90107.23471  64252.32335
# 7 1995-07-01    110128.0423        52113.12157  91441.24768  63722.70055
# 8 1995-08-01    112329.4376        52232.19868  92361.31512  64432.60005
# 9 1995-09-01    104473.1096        51471.61353  93273.12245  64509.54767
#
#          Brent      Bromley       Camden      Croydon       Ealing  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498
# 5  73704.04743  81542.61561  119929.2782   68844.9169  82077.05525
# 6  74310.48167  82382.83435  121887.4625  69052.51103  81630.66181
# 7  74127.03788  82898.52264  124027.5768  69142.48112   82352.2226
# 8   73547.0411  82054.37156  125529.8039  68993.42545  82706.65927
# 9  73789.54287  81440.43008  120596.8511  69393.50023  82011.08271
#
#        Enfield    Greenwich      Hackney Hammersmith & Fulham     Haringey  \
# 0    E09000010    E09000011    E09000012            E09000013    E09000014
# 1  72514.69096  62300.10169  61296.52637          124902.8602  76287.56947
# 2  73155.19746  60993.26863  63187.08332           122087.718  78901.21036
# 3  72190.44144  61377.83464  63593.29935          120635.9467  78521.94855
# 4  71442.92235   61927.7246  65139.64403          121424.6241  79545.57477
#  19  Islington             330 non-null    object
#  20  Kensington & Chelsea  330 non-null    object
#  21  Kingston upon Thames  330 non-null    object
#  22  Lambeth               330 non-null    object
#  23  Lewisham              330 non-null    object
#  24  Merton                330 non-null    object
#  25  Newham                330 non-null    object
#  26  Redbridge             330 non-null    object
#  27  Richmond upon Thames  330 non-null    object
#  28  Southwark             330 non-null    object
#  29  Sutton                330 non-null    object
#  30  Tower Hamlets         330 non-null    object
#  31  Waltham Forest        330 non-null    object
#  32  Wandsworth            330 non-null    object
#  33  Westminster           330 non-null    object
#  34  Unnamed: 34           0 non-null      float64
#  35  Inner London          330 non-null    object
#  36  Outer London          330 non-null    object
#  37  Unnamed: 37           0 non-null      float64
#  38  NORTH EAST            330 non-null    object
#  39  NORTH WEST            330 non-null    object
#  40  YORKS & THE HUMBER    330 non-null    object
#  41  EAST MIDLANDS         330 non-null    object
#  42  WEST MIDLANDS         330 non-null    object
#  43  EAST OF ENGLAND       330 non-null    object
#  44  LONDON                330 non-null    object
#  45  SOUTH EAST            330 non-null    object
#  46  SOUTH WEST            330 non-null    object
#  47  Unnamed: 47           0 non-null      float64
#  48  England               330 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(45)
# memory usage: 126.5+ KB

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties.drop(['Unnamed: 47', 'Unnamed: 34', 'Unnamed: 37'],
        axis=1, inplace=True)

(properties.isna().sum()/len(properties)).sort_values(ascending=False)
# Out:
# Unnamed: 0              0.00303
# Inner London            0.00000
# Newham                  0.00000
# Redbridge               0.00000
# Richmond upon Thames    0.00000
# Southwark               0.00000
# Sutton                  0.00000
# Tower Hamlets           0.00000
# Waltham Forest          0.00000
# Wandsworth              0.00000
# Westminster             0.00000
# Outer London            0.00000
# City of London          0.00000
# NORTH EAST              0.00000
# NORTH WEST              0.00000
# YORKS & THE HUMBER      0.00000
# EAST MIDLANDS           0.00000
# WEST MIDLANDS           0.00000
# EAST OF ENGLAND         0.00000
# LONDON                  0.00000
# SOUTH EAST              0.00000
# SOUTH WEST              0.00000
# Merton                  0.00000
# Lewisham                0.00000
# Lambeth                 0.00000
# Kingston upon Thames    0.00000
# Barking & Dagenham      0.00000
# Barnet                  0.00000
# Bexley                  0.00000
# Brent                   0.00000
# Bromley                 0.00000
# Camden                  0.00000
# Croydon                 0.00000
# Ealing                  0.00000
# Enfield                 0.00000
# Greenwich               0.00000
# Hackney                 0.00000
# Hammersmith & Fulham    0.00000
# Haringey                0.00000
# Harrow                  0.00000
# Havering                0.00000
# Hillingdon              0.00000
# Hounslow                0.00000
# Islington               0.00000
# Kensington & Chelsea    0.00000
# England                 0.00000
# dtype: float64

# %%
df = properties.copy(deep=True)
properties.index
df.rename({'Unnamed: 0': 'year'}, axis=1, inplace=True)
df.head()
# Out:
#         year City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
#
# 2   46051.57066   49341.29029     56593.59475  72777.93709  63715.02399
# 3   45383.82395   49442.17973     56171.18278  73896.84204  64113.60858
# 4   46124.23045   49455.93299     56567.89582  74455.28754  64623.22395
#
#     SOUTH WEST      England
# 0    E12000009    E92000001
# 1   54705.1579  53202.77128
# 2  54356.14843   53096.1549
# 3  53583.07667   53201.2843
# 4  54786.01938   53590.8548

# %%
# (pd.Series('year')).append(properties.iloc[0][1:])
df.drop(0, inplace=True)

# %%
df.set_index('year', inplace=True, drop=True)

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
df.columns
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')

# %%
# df.columns=properties.iloc[0][1:]

df.head()
# Out:
#            City of London Barking & Dagenham       Barnet       Bexley  \
# year
# 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
# 1995-05-01    84409.14932        53042.24852  90258.00033  63997.13588
#
#                   Brent      Bromley       Camden      Croydon       Ealing  \
# year
# 1995-01-01  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# 1995-02-01  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551
# 1995-03-01  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288
# 1995-04-01  72965.63094  81124.41227   120097.899  68610.04641  82188.90498
# 1995-05-01  73704.04743  81542.61561  119929.2782   68844.9169  82077.05525
#
#                 Enfield    Greenwich      Hackney Hammersmith & Fulham  \
# year
# 1995-01-01  72514.69096  62300.10169  61296.52637          124902.8602
# 1995-02-01  73155.19746  60993.26863  63187.08332           122087.718
# 1995-03-01  72190.44144  61377.83464  63593.29935          120635.9467
# 1995-04-01  71442.92235   61927.7246  65139.64403          121424.6241
# 1995-05-01  70630.77955  63512.99103  66193.99212           124433.539
#
#                Haringey       Harrow     Havering   Hillingdon     Hounslow  \
# year
# 1995-01-01  76287.56947  84769.52599  68000.13774  73834.82964  72231.70537
# 1995-02-01  78901.21036  83396.10525  69393.51294   75031.0696  71051.55852
# 1995-03-01  78521.94855  83416.23759  69368.02407  74188.66949  72097.99411
# 1995-04-01  79545.57477  83567.88439  69444.26215  73911.40591  71890.28339
# 1995-05-01   79374.0349  83853.65615  68534.52248  73117.12416  72877.47219
#
#               Islington Kensington & Chelsea Kingston upon Thames  \
# year
Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 329 entries, 1995-01-01 to 2022-05-01
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City of London        329 non-null    object
#  1   Barking & Dagenham    329 non-null    object
#  2   Barnet                329 non-null    object
#  3   Bexley                329 non-null    object
#  4   Brent                 329 non-null    object
#  5   Bromley               329 non-null    object
#  6   Camden                329 non-null    object
#  7   Croydon               329 non-null    object
#  8   Ealing                329 non-null    object
#  9   Enfield               329 non-null    object
#  10  Greenwich             329 non-null    object
#  11  Hackney               329 non-null    object
#  12  Hammersmith & Fulham  329 non-null    object
#  13  Haringey              329 non-null    object
#  14  Harrow                329 non-null    object
#  15  Havering              329 non-null    object
#  16  Hillingdon            329 non-null    object
#  17  Hounslow              329 non-null    object
#  18  Islington             329 non-null    object
#  19  Kensington & Chelsea  329 non-null    object
#  20  Kingston upon Thames  329 non-null    object
#  21  Lambeth               329 non-null    object
#  22  Lewisham              329 non-null    object
#  23  Merton                329 non-null    object
#  24  Newham                329 non-null    object
#  25  Redbridge             329 non-null    object
#  26  Richmond upon Thames  329 non-null    object
#  27  Southwark             329 non-null    object
#  28  Sutton                329 non-null    object
#  29  Tower Hamlets         329 non-null    object
#  30  Waltham Forest        329 non-null    object
#  31  Wandsworth            329 non-null    object
#  32  Westminster           329 non-null    object
#  33  Inner London          329 non-null    object
#  34  Outer London          329 non-null    object
#  35  NORTH EAST            329 non-null    object
#  36  NORTH WEST            329 non-null    object
#  37  YORKS & THE HUMBER    329 non-null    object
#  38  EAST MIDLANDS         329 non-null    object
#  39  WEST MIDLANDS         329 non-null    object
#  40  EAST OF ENGLAND       329 non-null    object
#  41  LONDON                329 non-null    object
#  42  SOUTH EAST            329 non-null    object
#  43  SOUTH WEST            329 non-null    object
#  44  England               329 non-null    object
# dtypes: object(45)
# memory usage: 118.2+ KB

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
df.describe()
# Out:
#         City of London  Barking & Dagenham       Barnet       Bexley  \
# count        329.00000            329.0000    329.00000    329.00000
# unique       329.00000            329.0000    329.00000    329.00000
# top        91448.98487          50460.2266  93284.51832  64958.09036
# freq           1.00000              1.0000      1.00000      1.00000
#
#               Brent      Bromley       Camden      Croydon       Ealing  \
# count     329.00000    329.00000     329.0000    329.00000    329.00000
# unique    329.00000    329.00000     329.0000    329.00000    329.00000
# top     71306.56698  81671.47692  120932.8881  69158.16225  79885.89069
# freq        1.00000      1.00000       1.0000      1.00000      1.00000
#
#             Enfield    Greenwich      Hackney  Hammersmith & Fulham  \
# count     329.00000    329.00000    329.00000              329.0000
# unique    329.00000    329.00000    329.00000              329.0000
# top     72514.69096  62300.10169  61296.52637           124902.8602
# freq        1.00000      1.00000      1.00000                1.0000
#
#            Haringey       Harrow     Havering   Hillingdon     Hounslow  \
# count     329.00000    329.00000    329.00000    329.00000    329.00000
# unique    329.00000    329.00000    329.00000    329.00000    329.00000
# top     76287.56947  84769.52599  68000.13774  73834.82964  72231.70537
# freq        1.00000      1.00000      1.00000      1.00000      1.00000
#
#           Islington  Kensington & Chelsea  Kingston upon Thames      Lambeth  \
# count     329.00000              329.0000             329.00000    329.00000
# unique    329.00000              329.0000             329.00000    329.00000
# top     92516.48557           182694.8326           80875.84843  67770.98843
# freq        1.00000                1.0000               1.00000      1.00000
#
#            Lewisham      Merton       Newham    Redbridge  \
# count     329.00000    329.0000    329.00000    329.00000
# unique    329.00000    329.0000    329.00000    329.00000
# top     60491.26109  82070.6133  53539.31919  72189.58437
# freq        1.00000      1.0000      1.00000      1.00000
#
#         Richmond upon Thames    Southwark       Sutton  Tower Hamlets  \
# count               329.0000    329.00000    329.00000      329.00000
# unique              329.0000    329.00000    329.00000      329.00000
# top              109326.1245  67885.20344  71536.97357    59865.18995
# freq                  1.0000      1.00000      1.00000        1.00000
#
#         Waltham Forest   Wandsworth  Westminster  Inner London  Outer London  \
# count        329.00000    329.00000     329.0000      329.0000     329.00000
# unique       329.00000    329.00000     329.0000      329.0000     329.00000
# top        61319.44913  88559.04381  133025.2772    78251.9765   72958.79836
# freq           1.00000      1.00000       1.0000        1.0000       1.00000
#
#          NORTH EAST   NORTH WEST  YORKS & THE HUMBER  EAST MIDLANDS  \
# count     329.00000    329.00000           329.00000      329.00000
# unique    329.00000    329.00000           329.00000      329.00000
# top     42076.35411  43958.48001         44803.42878    45544.52227
# freq        1.00000      1.00000             1.00000        1.00000
#
#         WEST MIDLANDS  EAST OF ENGLAND       LONDON   SOUTH EAST  SOUTH WEST  \
# count       329.00000         329.0000    329.00000    329.00000    329.0000
# unique      329.00000         329.0000    329.00000    329.00000    329.0000
# top       48527.52339       56701.5961  74435.76052  64018.87894  54705.1579
# freq          1.00000           1.0000      1.00000      1.00000      1.0000
#
#             England
# count     329.00000
# unique    329.00000
# top     53202.77128
# freq        1.00000

# %%
import numpy as np

df = df.astype(np.float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 329 entries, 1995-01-01 to 2022-05-01
# Data columns (total 45 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City of London        329 non-null    float64
#  1   Barking & Dagenham    329 non-null    float64
#  2   Barnet                329 non-null    float64
#  3   Bexley                329 non-null    float64
#  4   Brent                 329 non-null    float64
#  5   Bromley               329 non-null    float64
#  6   Camden                329 non-null    float64
#  7   Croydon               329 non-null    float64
#  8   Ealing                329 non-null    float64
#  9   Enfield               329 non-null    float64
#  10  Greenwich             329 non-null    float64
#  11  Hackney               329 non-null    float64
#  12  Hammersmith & Fulham  329 non-null    float64
#  13  Haringey              329 non-null    float64
#  14  Harrow                329 non-null    float64
#  15  Havering              329 non-null    float64
#  16  Hillingdon            329 non-null    float64
#  17  Hounslow              329 non-null    float64
#  18  Islington             329 non-null    float64
#  19  Kensington & Chelsea  329 non-null    float64
#  20  Kingston upon Thames  329 non-null    float64
#  21  Lambeth               329 non-null    float64
#  22  Lewisham              329 non-null    float64
#  23  Merton                329 non-null    float64
#  24  Newham                329 non-null    float64
#  25  Redbridge             329 non-null    float64
#  26  Richmond upon Thames  329 non-null    float64
#  27  Southwark             329 non-null    float64
#  28  Sutton                329 non-null    float64
#  29  Tower Hamlets         329 non-null    float64
#  30  Waltham Forest        329 non-null    float64
#  31  Wandsworth            329 non-null    float64
#  32  Westminster           329 non-null    float64
#  33  Inner London          329 non-null    float64
#  34  Outer London          329 non-null    float64
#  35  NORTH EAST            329 non-null    float64
#  36  NORTH WEST            329 non-null    float64
#  37  YORKS & THE HUMBER    329 non-null    float64
#  38  EAST MIDLANDS         329 non-null    float64
#  39  WEST MIDLANDS         329 non-null    float64
#  40  EAST OF ENGLAND       329 non-null    float64
#  41  LONDON                329 non-null    float64
#  42  SOUTH EAST            329 non-null    float64
#  43  SOUTH WEST            329 non-null    float64
#  44  England               329 non-null    float64
# dtypes: float64(45)
# memory usage: 118.2 KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# The London boroughs are the 32 local authority districts that together with the City of London make up the administrative area of Greater London
df.columns
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')

# %%
properties.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Inner London', 'Outer London', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')

# %%
borough = df.iloc[:,1:33]
borough.shape
# Out:
# (329, 32)

# %%
borough.head()
# Out:
#             Barking & Dagenham       Barnet       Bexley        Brent  \
# year
# 1995-01-01         50460.22660  93284.51832  64958.09036  71306.56698
# 1995-02-01         51085.77983  93190.16963  64787.92069  72022.26197
# 1995-03-01         51268.96956  92247.52435  64367.49344  72015.76274
# 1995-04-01         53133.50526  90762.87492  64277.66881  72965.63094
# 1995-05-01         53042.24852  90258.00033  63997.13588  73704.04743
#
#                 Bromley       Camden      Croydon       Ealing      Enfield  \
plt.xlabel('year_month')
plt.ylabel('Average price')
plt.legend(loc='upper left')
plt.title('Barking & Dagenham vs Barnet')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
borough.index.year
# Out:
# Int64Index([1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995, 1995,
#             ...
#             2021, 2021, 2021, 2021, 2021, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='year', length=329)

# %%
borough['Year'] = borough.index.year
# Out:
# /var/folders/3j/dhs8gmxj1wv7j6tk8_jzmv1c0000gn/T/ipykernel_97415/2313376484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   borough['Year'] = borough.index.year

# %%
by_year = borough.groupby('Year').mean()
(by_year.max()-by_year.min()).sort_values(ascending=False)
# Kensington & Chelsea
# Out:
# Kensington & Chelsea    1.189538e+06
# Westminster             9.310824e+05
# Camden                  7.446915e+05
# Richmond upon Thames    6.449516e+05
# Hammersmith & Fulham    6.414813e+05
# Islington               6.192879e+05
# Wandsworth              5.529289e+05
# Hackney                 5.488867e+05
# Haringey                5.067604e+05
# Barnet                  4.938320e+05
# Merton                  4.806107e+05
# Lambeth                 4.707671e+05
# Southwark               4.680282e+05
# Brent                   4.581805e+05
# Ealing                  4.469792e+05
# Kingston upon Thames    4.445794e+05
# Harrow                  4.248220e+05
# Waltham Forest          4.242579e+05
# Bromley                 4.057269e+05
# Tower Hamlets           4.055805e+05
# Redbridge               4.013173e+05
# Lewisham                3.887882e+05
# Hillingdon              3.755214e+05
# Enfield                 3.679842e+05
# Hounslow                3.604114e+05
# Greenwich               3.567838e+05
# Sutton                  3.538075e+05
# Newham                  3.471193e+05
# Havering                3.458736e+05
# Croydon                 3.444540e+05
# Bexley                  3.254533e+05
# Barking & Dagenham      2.909232e+05
# dtype: float64

# %%
plt.plot(by_year['Kensington & Chelsea'], '+',
         color='r', label='Kensington & Chelsea')
plt.plot(by_year['Barking & Dagenham'], '+',
         color='b', label='Barking & Dagenham')
plt.xlabel('Year')
plt.ylabel('Average price')
plt.legend(loc='best')
plt.title('Kensington & Chelsea vs Barking & Dagenham')
plt.show()

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(borough):
    ratio = (by_year[borough].iloc[23])/(by_year[borough].iloc[3])
    return round(ratio,2)

for i in by_year.columns:
    ratio = create_price_ratio(i)
    print(
        f'The ratio of average price between 1998 and 2018 in {i} borough is {ratio}')
# Out:
# The ratio of average price between 1998 and 2018 in Barking & Dagenham borough is 4.9
# The ratio of average price between 1998 and 2018 in Barnet borough is 4.36
# The ratio of average price between 1998 and 2018 in Bexley borough is 4.25
# The ratio of average price between 1998 and 2018 in Brent borough is 4.89
# The ratio of average price between 1998 and 2018 in Bromley borough is 4.09
# The ratio of average price between 1998 and 2018 in Camden borough is 4.94
# The ratio of average price between 1998 and 2018 in Croydon borough is 4.2
# The ratio of average price between 1998 and 2018 in Ealing borough is 4.31
# The ratio of average price between 1998 and 2018 in Enfield borough is 4.26
# The ratio of average price between 1998 and 2018 in Greenwich borough is 4.76
# The ratio of average price between 1998 and 2018 in Hackney borough is 6.2
# The ratio of average price between 1998 and 2018 in Hammersmith & Fulham borough is 4.14
# The ratio of average price between 1998 and 2018 in Haringey borough is 5.13
# The ratio of average price between 1998 and 2018 in Harrow borough is 4.06
# The ratio of average price between 1998 and 2018 in Havering borough is 4.33
# The ratio of average price between 1998 and 2018 in Hillingdon borough is 4.2
# The ratio of average price between 1998 and 2018 in Hounslow borough is 3.98
# The ratio of average price between 1998 and 2018 in Islington borough is 4.84
# The ratio of average price between 1998 and 2018 in Kensington & Chelsea borough is 5.08
# The ratio of average price between 1998 and 2018 in Kingston upon Thames borough is 4.27
# The ratio of average price between 1998 and 2018 in Lambeth borough is 4.96
# The ratio of average price between 1998 and 2018 in Lewisham borough is 5.45
# The ratio of average price between 1998 and 2018 in Merton borough is 4.74
# The ratio of average price between 1998 and 2018 in Newham borough is 5.31
# The ratio of average price between 1998 and 2018 in Redbridge borough is 4.47
# The ratio of average price between 1998 and 2018 in Richmond upon Thames borough is 4.01
# The ratio of average price between 1998 and 2018 in Southwark borough is 5.52
# The ratio of average price between 1998 and 2018 in Sutton borough is 4.12
# The ratio of average price between 1998 and 2018 in Tower Hamlets borough is 4.63
# The ratio of average price between 1998 and 2018 in Waltham Forest borough is 5.83
# The ratio of average price between 1998 and 2018 in Wandsworth borough is 4.76
# The ratio of average price between 1998 and 2018 in Westminster borough is 5.35

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# * The average price largely increases in the last 20 years.
# * In some boroughs like Waltham Forest, Lewisham and Westiminster, the magnitude of increasement is bigger than other areas.
